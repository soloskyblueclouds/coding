# %%
import numpy as np

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
np.ones(4)
# Out:
# array([1., 1., 1., 1.])

# %%
np.empty(5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.empty(6)
# Out:
# array([4.65451355e-310, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000])

# %%
np.empty(15)
# Out:
# array([4.65451355e-310, 1.03977794e-312, 1.03977794e-312, 9.54898106e-313,
#        1.03977794e-312, 1.01855798e-312, 1.23075756e-312, 1.18831764e-312,
#        1.08221785e-312, 9.76118064e-313, 1.03977794e-312, 1.18831764e-312,
#        1.06099790e-312, 4.44659081e-322, 0.00000000e+000])

# %%
a1d = np.array([1,6,5])
a1d
# Out:
# array([1, 6, 5])

# %%
a2d = np.array([[3,4],[6,7]])
a2d
# Out:
# array([[3, 4],
#        [6, 7]])

# %%
a3d = np.array([[[6,6],[9,0]],[[5,5],[0,4]]])
a3d
# Out:
# array([[[6, 6],
#         [9, 0]],
#
#        [[5, 5],
#         [0, 4]]])

# %%
import numpy as np 
import matplotlib.pyplot as plt
